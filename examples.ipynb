# %% [markdown]
# # Rightmove House Prices API — Examples
#
# This notebook demonstrates how to use the API endpoints.
#
# **Prerequisites:** Start the server with `uvicorn app.main:app --reload`

# %%
import json
import requests

BASE = "http://localhost:8000"

def pp(resp):
    """Pretty-print a response."""
    print(f"{resp.status_code} {resp.request.method} {resp.request.url}")
    try:
        print(json.dumps(resp.json(), indent=2))
    except Exception:
        print(resp.text[:500])

# %% [markdown]
# ## 1. Basic Postcode Scrape
#
# Fast path — extracts data from the listing page (single HTTP request).

# %%
resp = requests.post(f"{BASE}/scrape/postcode/E1W1AT", params={"max_properties": 10})
pp(resp)
# Out:
# 200 POST http://localhost:8000/scrape/postcode/E1W1AT?max_properties=10
# {
#   "message": "Scraped 10 properties for postcode E1W1AT",
#   "properties_scraped": 10
# }

# %% [markdown]
# ## 2. Multi-Page Scrape
#
# Scrape 3 listing pages to get more properties.

# %%
resp = requests.post(f"{BASE}/scrape/postcode/SW1A2AA", params={"pages": 3, "max_properties": 30})
pp(resp)

# %% [markdown]
# ## 3. Single Property with Floorplan
#
# Scrape a single property detail page and extract floorplan URLs.

# %%
# First, get a property URL from a postcode scrape
props = requests.get(f"{BASE}/properties", params={"postcode": "E1W", "limit": 1}).json()
if props:
    url = props[0].get("url")
    print(f"Using property URL: {url}")
    if url:
        resp = requests.post(f"{BASE}/scrape/property", json={"url": url, "floorplan": True})
        pp(resp)
else:
    print("No properties found. Run cell 1 first.")

# %% [markdown]
# ## 4. Postcode Scrape with Detail Pages and Floorplans
#
# Slow path — visits individual detail pages for richer data.
# `link_count=3` limits detail page visits. `floorplan=true` extracts floorplan URLs.

# %%
resp = requests.post(
    f"{BASE}/scrape/postcode/E1W1AT",
    params={"link_count": 3, "floorplan": True},
)
pp(resp)

# %% [markdown]
# ## 5. Query Properties with Filters
#
# Search stored properties by postcode, type, and bedroom count.

# %%
resp = requests.get(f"{BASE}/properties", params={
    "postcode": "E1W",
    "min_bedrooms": 2,
    "limit": 5,
})
pp(resp)

# %% [markdown]
# ## 6. Property Detail with Sale History
#
# Fetch a single property by ID to see its full sale history.

# %%
# Get the first property ID
props = requests.get(f"{BASE}/properties", params={"limit": 1}).json()
if props:
    pid = props[0]["id"]
    resp = requests.get(f"{BASE}/properties/{pid}")
    pp(resp)
else:
    print("No properties stored yet.")
# Out:
# 200 GET http://localhost:8000/properties/10
# {
#   "id": 10,
#   "address": "Flat 21, Ivory House, East Smithfield, London E1W 1AT",
#   "postcode": "E1W 1AT",
#   "property_type": "FLAT",
#   "bedrooms": 2,
#   "bathrooms": 2,
#   "url": "https://www.rightmove.co.uk/house-prices/details/8a4c2bf1-687f-4cb2-aeb7-1f932dce12a0",
#   "created_at": "2026-02-05T16:45:13.062717",
#   "updated_at": "2026-02-05T16:45:13.062717",
#   "extra_features": null,
#   "sales": [
#     {
#       "id": 24,
#       "date_sold": "10 Jun 2005",
#       "price": "\u00a3661,500",
#       "price_change_pct": "",
#       "property_type": "",
#       "tenure": "LEASEHOLD"
#     },
#     {
#       "id": 23,
#       "date_sold": "18 Dec 2017",
#       "price": "\u00a3900,000",
#       "price_change_pct": "",
#       "property_type": "",
#       "tenure": "LEASEHOLD"
#     }
#   ]
# }

# %% [markdown]
# ## 7. Postcode Summary
#
# List all scraped postcodes with property counts.

# %%
resp = requests.get(f"{BASE}/postcodes")
pp(resp)

# %% [markdown]
# ## 8. Multi-Postcode Workflow
#
# Scrape several postcodes, then query the combined results.

# %%
postcodes = ["E1W1AT", "SE10DX", "N19AG"]
for pc in postcodes:
    resp = requests.post(f"{BASE}/scrape/postcode/{pc}", params={"max_properties": 10})
    data = resp.json()
    print(f"{pc}: {data.get('properties_scraped', 0)} properties")

print("\n--- Postcode summary ---")
resp = requests.get(f"{BASE}/postcodes")
for item in resp.json():
    print(f"  {item['postcode']}: {item['property_count']} properties")

# %% [markdown]
# ## 9. Reading the Database Directly
#
# You can also query the SQLite database directly, bypassing the API.
# This is useful for data analysis, bulk exports, or integration with pandas.

# %%
import sqlite3
import json
import pandas as pd

DB_PATH = "rightmove.db"  # relative to where the server was started
conn = sqlite3.connect(DB_PATH)

# List all tables
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name", conn)
print("Tables:", tables["name"].tolist())
# Out:
# Tables: ['properties', 'sales']

# %% [markdown]
# ### 9a. Browse all properties

# %%
pd.read_sql_query(
    "SELECT id, address, postcode, property_type, bedrooms, bathrooms FROM properties LIMIT 10",
    conn,
)
# Out:
#    id                                            address postcode  \
# 0   1  Flat 6, Ivory House, East Smithfield, London E...  E1W 1AT
# 1   2  Flat 23, Ivory House, East Smithfield, London ...  E1W 1AT
# 2   3  Flat 25, Ivory House, East Smithfield, London ...  E1W 1AT
# 3   4  Flat 30, Ivory House, East Smithfield, London ...  E1W 1AT
# 4   5  Flat 32, Ivory House, East Smithfield, London ...  E1W 1AT
# 5   6  Flat 29, Ivory House, East Smithfield, London ...  E1W 1AT
# 6   7  Flat 34, Ivory House, East Smithfield, London ...  E1W 1AT
# 7   8  Flat 15, Ivory House, East Smithfield, London ...  E1W 1AT
# 8   9  Flat 4, Ivory House, East Smithfield, London E...  E1W 1AT
# 9  10  Flat 21, Ivory House, East Smithfield, London ...  E1W 1AT
#
#   property_type  bedrooms  bathrooms
# 0          FLAT         1          1
# 1          FLAT         1          1
# 2          FLAT         4          0
# 3          FLAT         2          1
# 4          FLAT         1          1
# 5          FLAT         4          4
# 6          FLAT         1          0
# 7          FLAT         0          0
# 8          FLAT         2          0
# 9          FLAT         2          2

# %% [markdown]
# ### 9b. Sale history for a property

# %%
# Pick the first property and show its sales
first_id = pd.read_sql_query("SELECT id, address FROM properties LIMIT 1", conn)
if not first_id.empty:
    pid = int(first_id.iloc[0]["id"])
    print(f"Sales for: {first_id.iloc[0]['address']}\n")
    display(pd.read_sql_query(
        "SELECT date_sold, price, tenure, property_type FROM sales WHERE property_id = ? ORDER BY rowid",
        conn, params=(pid,),
    ))
else:
    print("No properties in the database yet.")
# Out:
# Sales for: Flat 15, Ivory House, East Smithfield, London E1W 1AT
#      date_sold       price     tenure property_type
# 0  30 Oct 2018  £1,375,000  LEASEHOLD
# 1  22 Dec 2005    £670,000  LEASEHOLD

# %% [markdown]
# ### 9c. Join properties with their latest sale

# %%
pd.read_sql_query("""
    SELECT p.address, p.postcode, p.bedrooms, s.date_sold, s.price, s.tenure
    FROM properties p
    JOIN sales s ON s.property_id = p.id
    WHERE s.id = (
        SELECT s2.id FROM sales s2
        WHERE s2.property_id = p.id
        ORDER BY s2.rowid DESC LIMIT 1
    )
    ORDER BY p.postcode
    LIMIT 15
""", conn)
# Out:
#                                              address postcode  bedrooms  \
# 0  Flat 6, Ivory House, East Smithfield, London E...  E1W 1AT         1
# 1  Flat 23, Ivory House, East Smithfield, London ...  E1W 1AT         1
# 2  Flat 25, Ivory House, East Smithfield, London ...  E1W 1AT         4
# 3  Flat 30, Ivory House, East Smithfield, London ...  E1W 1AT         2
# 4  Flat 32, Ivory House, East Smithfield, London ...  E1W 1AT         1
# 5  Flat 29, Ivory House, East Smithfield, London ...  E1W 1AT         4
# 6  Flat 34, Ivory House, East Smithfield, London ...  E1W 1AT         1
# 7  Flat 15, Ivory House, East Smithfield, London ...  E1W 1AT         0
# 8  Flat 4, Ivory House, East Smithfield, London E...  E1W 1AT         2
# 9  Flat 21, Ivory House, East Smithfield, London ...  E1W 1AT         2
#
#      date_sold       price     tenure
# 0  04 Nov 2005    £397,000  Leasehold
# 1   6 Jul 2006    £499,500  LEASEHOLD
# 2   2 Aug 2006  £1,800,000  LEASEHOLD
# 3   1 Sep 2006    £425,000  LEASEHOLD
# 4  30 Jun 2006    £470,000  LEASEHOLD
# 5  20 Oct 2006  £1,810,000  LEASEHOLD
# 6  22 Aug 2008    £480,000  LEASEHOLD
# 7  22 Dec 2005    £670,000  LEASEHOLD
# 8   6 May 2005    £660,000  LEASEHOLD
# 9  10 Jun 2005    £661,500  LEASEHOLD

# %% [markdown]
# ### 9d. Aggregate stats by postcode

# %%
pd.read_sql_query("""
    SELECT
        p.postcode,
        COUNT(DISTINCT p.id) AS properties,
        COUNT(s.id) AS total_sales,
        ROUND(AVG(p.bedrooms), 1) AS avg_beds,
        GROUP_CONCAT(DISTINCT p.property_type) AS types
    FROM properties p
    LEFT JOIN sales s ON s.property_id = p.id
    WHERE p.postcode IS NOT NULL
    GROUP BY p.postcode
    ORDER BY properties DESC
""", conn)
# Out:
#   postcode  properties  total_sales  avg_beds types
# 0  E1W 1AT          10           24       1.8  FLAT

# %% [markdown]
# ### 9e. Properties with floorplan URLs

# %%
df_fp = pd.read_sql_query(
    "SELECT address, floorplan_urls FROM properties WHERE floorplan_urls IS NOT NULL LIMIT 10",
    conn,
)
if not df_fp.empty:
    # Parse JSON column into a proper list
    df_fp["floorplan_urls"] = df_fp["floorplan_urls"].apply(json.loads)
    display(df_fp)
else:
    print("No floorplan URLs stored yet. Run a scrape with floorplan=true first (cells 3 or 4).")
# Out:
# No floorplan URLs stored yet. Run a scrape with floorplan=true first (cells 3 or 4).

# %% [markdown]
# ### 9f. Load into pandas DataFrame

# %%
df_props = pd.read_sql_query("SELECT * FROM properties", conn)
df_sales = pd.read_sql_query("SELECT * FROM sales", conn)

print(f"Properties: {len(df_props)} rows, Sales: {len(df_sales)} rows\n")
print("--- Properties ---")
display(df_props[["address", "postcode", "property_type", "bedrooms", "bathrooms"]].head())
print("\n--- Sales ---")
display(df_sales[["property_id", "date_sold", "price", "tenure"]].head())
# Out:
# Properties: 10 rows, Sales: 24 rows
#
# --- Properties ---
#                                              address postcode property_type  \
# 0  Flat 6, Ivory House, East Smithfield, London E...  E1W 1AT          FLAT
# 1  Flat 23, Ivory House, East Smithfield, London ...  E1W 1AT          FLAT
# 2  Flat 25, Ivory House, East Smithfield, London ...  E1W 1AT          FLAT
# 3  Flat 30, Ivory House, East Smithfield, London ...  E1W 1AT          FLAT
# 4  Flat 32, Ivory House, East Smithfield, London ...  E1W 1AT          FLAT
#
#    bedrooms  bathrooms
# 0         1          1
# 1         1          1
# 2         4          0
# 3         2          1
# 4         1          1
# --- Sales ---
#    property_id    date_sold       price     tenure
# 0            1   7 Mar 2025    £752,000  LEASEHOLD
# 1            1   4 Nov 2005    £397,000  LEASEHOLD
# 2            2  15 Nov 2024    £870,000  LEASEHOLD
# 3            2   6 Jul 2006    £499,500  LEASEHOLD
# 4            3   1 Nov 2022  £3,400,000  LEASEHOLD

# %% [markdown]
# ### 9g. Export to CSV

# %%
df = pd.read_sql_query("""
    SELECT p.address, p.postcode, p.property_type, p.bedrooms, p.bathrooms,
           s.date_sold, s.price, s.tenure
    FROM properties p
    JOIN sales s ON s.property_id = p.id
    ORDER BY p.postcode, p.address, s.rowid
""", conn)

out_path = "rightmove_export.csv"
df.to_csv(out_path, index=False)
print(f"Exported {len(df)} rows to {out_path}")
df.head()
# Out:
# Exported 24 rows to rightmove_export.csv
#                                              address postcode property_type  \
# 0  Flat 15, Ivory House, East Smithfield, London ...  E1W 1AT          FLAT
# 1  Flat 15, Ivory House, East Smithfield, London ...  E1W 1AT          FLAT
# 2  Flat 21, Ivory House, East Smithfield, London ...  E1W 1AT          FLAT
# 3  Flat 21, Ivory House, East Smithfield, London ...  E1W 1AT          FLAT
# 4  Flat 23, Ivory House, East Smithfield, London ...  E1W 1AT          FLAT
#
#    bedrooms  bathrooms    date_sold       price     tenure
# 0         0          0  30 Oct 2018  £1,375,000  LEASEHOLD
# 1         0          0  22 Dec 2005    £670,000  LEASEHOLD
# 2         2          2  18 Dec 2017    £900,000  LEASEHOLD
# 3         2          2  10 Jun 2005    £661,500  LEASEHOLD
# 4         1          1  15 Nov 2024    £870,000  LEASEHOLD

# %%
conn.close()
print("Database connection closed.")
# Out:
# Database connection closed.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas as pd

pd.read_parquet('sales_data/enriched_properties.parquet ')
# Out:
#                                                 address  postcode  \
# 0        100, Amity Grove, Raynes Park, London SW20 0LJ  SW20 0LJ
# 1        100, Amity Grove, Raynes Park, London SW20 0LJ  SW20 0LJ
# 2        100, Amity Grove, Raynes Park, London SW20 0LJ  SW20 0LJ
# 3     100, Beverley Way, West Wimbledon, London SW20...  SW20 0AQ
# 4     100, Beverley Way, West Wimbledon, London SW20...  SW20 0AQ
# ...                                                 ...       ...
# 2225  Garden House, Cottenham Park Road, Wimbledon S...  SW20 0DR
# 2226  Garden House, Cottenham Park Road, Wimbledon S...  SW20 0DR
# 2227  Garden House, Cottenham Park Road, Wimbledon S...  SW20 0DR
# 2228  Garden House, Cottenham Park Road, Wimbledon S...  SW20 0DR
# 2229  Garden House, Cottenham Park Road, Wimbledon S...  SW20 0DR
#
#                property_type  bedrooms  bathrooms  \
# 0          Detached,Freehold         3          2
# 1          Detached,Freehold         3          2
# 2          Detached,Freehold         3          2
# 3     Semi-detached,Freehold         4          2
# 4     Semi-detached,Freehold         4          2
# ...                      ...       ...        ...
# 2225          Flat,Leasehold         2          0
# 2226          Flat,Leasehold         2          0
# 2227          Flat,Leasehold         2          0
# 2228          Flat,Leasehold         2          0
# 2229          Flat,Leasehold         2          0
#
#                                          extra_features floorplan_urls  \
# 0     ["Detached family home", "Three Double Bedroom...           None
# 1     ["Detached family home", "Three Double Bedroom...           None
# 2     ["Detached family home", "Three Double Bedroom...           None
# 3     ["CHAIN FREE", "Semi-Detached Mock Tudor Style...           None
# 4     ["CHAIN FREE", "Semi-Detached Mock Tudor Style...           None
# ...                                                 ...            ...
# 2225                                               None           None
# 2226                                               None           None
# 2227                                               None           None
# 2228                                               None           None
# 2229                                               None           None
#
#                                                     url    date_sold  \
# 0     https://www.rightmove.co.uk/house-prices/detai...  10 Jun 2013
# 1     https://www.rightmove.co.uk/house-prices/detai...  23 Feb 1996
# 2     https://www.rightmove.co.uk/house-prices/detai...  29 Aug 2024
# 3     https://www.rightmove.co.uk/house-prices/detai...  10 Aug 2012
# 4     https://www.rightmove.co.uk/house-prices/detai...   9 Mar 2021
# ...                                                 ...          ...
# 2225  https://www.rightmove.co.uk/house-prices/detai...  12 Apr 2002
# 2226  https://www.rightmove.co.uk/house-prices/detai...  29 Jan 1996
# 2227  https://www.rightmove.co.uk/house-prices/detai...  31 Aug 1999
# 2228  https://www.rightmove.co.uk/house-prices/detai...   5 Jun 1998
# 2229  https://www.rightmove.co.uk/house-prices/detai...   6 Feb 2009
#
#      date_sold_iso  ... swimming_pool  air_conditioning solar_panels  loft  \
# 0       2013-06-10  ...          None              None         None  None
# 1       1996-02-23  ...          None              None         None  None
# 2       2024-08-29  ...          None              None         None  None
# 3       2012-08-10  ...          None              None         None  None
# 4       2021-03-09  ...          None              None         None  None
# ...            ...  ...           ...               ...          ...   ...
# 2225    2002-04-12  ...          None              None         None  None
# 2226    1996-01-29  ...          None              None         None  None
# 2227    1999-08-31  ...          None              None         None  None
# 2228    1998-06-05  ...          None              None         None  None
# 2229    2009-02-06  ...          None              None         None  None
#
#      entrance_hall white_goods bay_window distance_to_station intercom  \
# 0             None        None       None                 NaN     None
# 1             None        None       None                 NaN     None
# 2             None        None       None                 NaN     None
# 3             None        None       None                 NaN     None
# 4             None        None       None                 NaN     None
# ...            ...         ...        ...                 ...      ...
# 2225          None        None       None                 NaN     None
# 2226          None        None       None                 NaN     None
# 2227          None        None       None                 NaN     None
# 2228          None        None       None                 NaN     None
# 2229          None        None       None                 NaN     None
#
#      split_level
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
# ...          ...
# 2225        None
# 2226        None
# 2227        None
# 2228        None
# 2229        None
#
# [2230 rows x 55 columns]
