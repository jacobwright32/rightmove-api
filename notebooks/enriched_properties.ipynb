# %% [markdown]
# # Enriched Properties DataFrame
#
# Reads all properties from the SQLite database and parses the `extra_features` JSON column into structured columns using the feature parser (74 features total: 41 v1 + 23 v2 + 10 v3).

# %%
import sys
from pathlib import Path

# Add project root to path so we can import app modules
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

import sqlite3
import json
import pandas as pd
from app.feature_parser import parse_all_features
from app.constants import FEATURE_PARSER_KEYS

DB_PATH = PROJECT_ROOT / "uk_house_prices.db"

# Load all properties with extra_features from the database
conn = sqlite3.connect(str(DB_PATH))
df = pd.read_sql_query(
    "SELECT id, address, postcode, property_type, bedrooms, bathrooms, "
    "extra_features, url FROM properties "
    "WHERE extra_features IS NOT NULL",
    conn,
)
conn.close()

print(f"Loaded {len(df):,} properties with extra_features")
print(f"Feature parser keys: {len(FEATURE_PARSER_KEYS)} features")
df.head(3)
# Out:
# Loaded 205,371 properties with extra_features
# Feature parser keys: 74 features
#    id                                            address postcode  \
# 0   1  Flat 6, Ivory House, East Smithfield, London E...  E1W 1AT
# 1   2  Flat 23, Ivory House, East Smithfield, London ...  E1W 1AT
# 2   3  Flat 25, Ivory House, East Smithfield, London ...  E1W 1AT
#
#   property_type  bedrooms  bathrooms extra_features  \
# 0          FLAT         1          1             []
# 1          FLAT         1          1             []
# 2          FLAT         4          0             []
#
#                                                  url
# 0  https://www.rightmove.co.uk/house-prices/detai...
# 1  https://www.rightmove.co.uk/house-prices/detai...
# 2  https://www.rightmove.co.uk/house-prices/detai...

# %% [markdown]
# ## Parse extra_features into structured columns (74 features)

# %%
# Parse extra_features for each row
parsed = df["extra_features"].apply(parse_all_features).apply(pd.Series)

# Join parsed columns to original dataframe
enriched = pd.concat([df, parsed], axis=1)

NEW_COLS = list(parsed.columns)

# Split into v1, v2, v3 features
V1_FEATURES = [
    "epc_rating", "council_tax_band", "chain_free", "parking", "garden",
    "heating", "double_glazed", "lease_type", "lease_years", "receptions",
    "furnished", "period_property", "utility_room", "conservatory", "ensuite",
    "cloakroom", "floor_level", "sq_ft", "service_charge", "ground_rent",
    "wooden_floors", "gym", "lift", "dining_room", "ev_charger", "fireplace",
    "study", "shower_room", "fitted_wardrobes", "new_build", "concierge",
    "swimming_pool", "air_conditioning", "solar_panels", "loft",
    "entrance_hall", "white_goods", "bay_window", "distance_to_station",
    "intercom", "split_level",
]
V2_FEATURES = [
    "cellar", "roof_terrace", "high_ceilings", "open_plan", "gated",
    "purpose_built", "refurbished", "duplex", "penthouse", "own_front_door",
    "private_entrance", "bike_storage", "cul_de_sac", "conservation_area",
    "annexe", "views", "underground_parking", "allocated_parking",
    "garden_facing", "property_era", "condition", "kitchen_type",
    "listed_building",
]
V3_FEATURES = [c for c in NEW_COLS if c not in V1_FEATURES and c not in V2_FEATURES]

print(f"Enriched: {len(enriched):,} rows, {len(enriched.columns)} columns")
print(f"  v1 features: {len(V1_FEATURES)}")
print(f"  v2 features: {len(V2_FEATURES)}")
print(f"  v3 features: {len(V3_FEATURES)} — {V3_FEATURES}")
enriched[["address", "postcode"] + V2_FEATURES + V3_FEATURES].head(10)
# Out:
# Enriched: 205,371 rows, 82 columns
#   v1 features: 41
#   v2 features: 23
#   v3 features: 10 — ['extended', 'outbuilding', 'potential_to_extend', 'walk_in_wardrobe', 'wet_room', 'integrated_appliances', 'side_access', 'video_entry', 'separate_living_room', 'laminate_flooring']
#                                              address postcode cellar  \
# 0  Flat 6, Ivory House, East Smithfield, London E...  E1W 1AT   None
# 1  Flat 23, Ivory House, East Smithfield, London ...  E1W 1AT   None
# 2  Flat 25, Ivory House, East Smithfield, London ...  E1W 1AT   None
# 3  Flat 30, Ivory House, East Smithfield, London ...  E1W 1AT   None
# 4  Flat 32, Ivory House, East Smithfield, London ...  E1W 1AT   None
# 5  Flat 29, Ivory House, East Smithfield, London ...  E1W 1AT   None
# 6  Flat 34, Ivory House, East Smithfield, London ...  E1W 1AT   None
# 7  Flat 15, Ivory House, East Smithfield, London ...  E1W 1AT   None
# 8  Flat 4, Ivory House, East Smithfield, London E...  E1W 1AT   None
# ...

# %% [markdown]
# ## Fill rates per column (all 74 features)

# %%
fill_rates = enriched[NEW_COLS].notna().sum().to_frame("filled")
fill_rates["total"] = len(enriched)
fill_rates["pct"] = (fill_rates["filled"] / fill_rates["total"] * 100).round(1)
fill_rates["version"] = fill_rates.index.map(
    lambda x: "v3 NEW" if x in V3_FEATURES else ("v2" if x in V2_FEATURES else "v1")
)
fill_rates = fill_rates.sort_values("pct", ascending=False)

print(f"{'Feature':<25} {'Filled':>8} {'Total':>8} {'Fill%':>7}  Version")
print("-" * 65)
for feat, row in fill_rates.iterrows():
    print(f"{feat:<25} {row['filled']:>8,.0f} {row['total']:>8,.0f} {row['pct']:>6.1f}%  {row['version']}")

# Summary
v1_f = fill_rates[fill_rates["version"] == "v1"]["filled"].sum()
v2_f = fill_rates[fill_rates["version"] == "v2"]["filled"].sum()
v3_f = fill_rates[fill_rates["version"] == "v3 NEW"]["filled"].sum()
total_filled = v1_f + v2_f + v3_f
print(f"\nTotal feature values extracted: {total_filled:,.0f}")
print(f"  v1: {v1_f:,.0f}")
print(f"  v2: {v2_f:,.0f}")
print(f"  v3 (new): {v3_f:,.0f}")
print(f"  New (v2+v3): {v2_f+v3_f:,.0f} ({(v2_f+v3_f)/total_filled*100:.1f}%)")
# Out:
# Feature                     Filled    Total   Fill%  Version
# -----------------------------------------------------------------
# garden                      79,699  205,371   38.8%  v1
# parking                     31,157  205,371   15.2%  v1
# kitchen_type                29,760  205,371   14.5%  v2
# epc_rating                  23,321  205,371   11.4%  v1
# floor_level                 21,657  205,371   10.5%  v1
# open_plan                   16,627  205,371    8.1%  v2
# receptions                  15,178  205,371    7.4%  v1
# lease_type                  14,613  205,371    7.1%  v1
# chain_free                  14,286  205,371    7.0%  v1
# sq_ft                       12,144  205,371    5.9%  v1
# ensuite                     11,820  205,371    5.8%  v1
# furnished                   10,934  205,371    5.3%  v1
# concierge                   10,280  205,371    5.0%  v1
# garden_facing                9,449  205,371    4.6%  v2
# ...

# %% [markdown]
# ## Value distributions for v2 + v3 features

# %%
for col in V2_FEATURES + V3_FEATURES:
    filled = enriched[col].dropna()
    if len(filled) == 0:
        continue
    print(f"\n{'='*50}")
    print(f"{col} ({len(filled):,} filled / {len(enriched):,} total = {len(filled)/len(enriched)*100:.1f}%)")
    print(f"{'='*50}")
    print(filled.value_counts().head(10).to_string())
# Out:
# ...
# cellar (3,474 filled / 205,371 total = 1.7%)
# ...
# cellar
# True    3474
#
# ...
# roof_terrace (5,126 filled / 205,371 total = 2.5%)
# ...
# roof_terrace
# True    5126
#
# ...
# high_ceilings (2,469 filled / 205,371 total = 1.2%)
# ...
# high_ceilings
# True    2469
#
# ...
# open_plan (16,627 filled / 205,371 total = 8.1%)
# ...
# open_plan
# True    16627
#
# ...
# gated (3,584 filled / 205,371 total = 1.7%)
# ...
# gated
# True    3584
#
# ...
# purpose_built (1,999 filled / 205,371 total = 1.0%)
# ...
# purpose_built
# True    1999
#
# ...
# refurbished (7,541 filled / 205,371 total = 3.7%)
# ...
# refurbished
# True    7541
#
# ...
# duplex (742 filled / 205,371 total = 0.4%)
# ...
# duplex
# True    742
#
# ...
# penthouse (636 filled / 205,371 total = 0.3%)
# ...
# penthouse
# True    636
#
# ...
# own_front_door (1,130 filled / 205,371 total = 0.6%)
# ...
# own_front_door
# True    1130
#
# ...
# private_entrance (1,065 filled / 205,371 total = 0.5%)
# ...
# private_entrance
# True    1065
#
# ...
# bike_storage (1,322 filled / 205,371 total = 0.6%)
# ...
# bike_storage
# True    1322
#
# ...

# %%
# v1 feature distributions (for reference)
for col in V1_FEATURES:
    filled = enriched[col].dropna()
    if len(filled) == 0:
        continue
    print(f"\n{'='*50}")
    print(f"{col} ({len(filled):,} filled / {len(enriched):,} total = {len(filled)/len(enriched)*100:.1f}%)")
    print(f"{'='*50}")
    print(filled.value_counts().head(10).to_string())
# Out:
# ...
# epc_rating (23,321 filled / 205,371 total = 11.4%)
# ...
# epc_rating
# G    19245
# D     1506
# C     1444
# B      569
# E      511
# F       35
# A       11
#
# ...
# council_tax_band (4,886 filled / 205,371 total = 2.4%)
# ...
# council_tax_band
# D    1289
# C    1047
# E    1003
# F     586
# G     517
# B     252
# H     128
# A      64
#
# ...
# chain_free (14,286 filled / 205,371 total = 7.0%)
# ...
# chain_free
# True     14242
# False       44
#
# ...
# parking (31,157 filled / 205,371 total = 15.2%)
# ...
# parking
# Parking       14906
# Off-street     9965
# Garage         5353
# Driveway        933
#
# ...
# garden (79,699 filled / 205,371 total = 38.8%)
# ...
# garden
# Garden             30055
# Private Garden     16177
# Balcony            15469
# Terrace             7700
# Communal Garden     7098
# Patio               3200
#
# ...
# heating (7,166 filled / 205,371 total = 3.5%)
# ...
# heating
# Gas Central        2724
# Underfloor         1762
# Central Heating    1459
# Other              1152
# Electric             69
#
# ...

# %% [markdown]
# ## Save enriched dataframe

# %%
output_path = PROJECT_ROOT / "sales_data" / "enriched_properties.parquet"
output_path.parent.mkdir(parents=True, exist_ok=True)
enriched.to_parquet(output_path, engine="pyarrow", compression="snappy", index=False)
print(f"Saved to {output_path}")
print(f"  {len(enriched):,} rows x {len(enriched.columns)} columns")
print(f"  Columns: {list(enriched.columns)}")
# Out:
# Saved to C:\dev\rightmove-api\sales_data\enriched_properties.parquet
#   205,371 rows x 82 columns
# ...
